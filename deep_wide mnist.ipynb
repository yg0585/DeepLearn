# %%
import tensorflow as tf
import numpy as np
import random

mnist = tf.keras.datasets.mnist

(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0

print(x_train.shape)
x_train = x_train.reshape(x_train.shape[0], x_train.shape[1] * x_train.shape[2])
x_test = x_test.reshape(x_test.shape[0], x_test.shape[1] * x_test.shape[2])

y_train = tf.keras.utils.to_categorical(y_train, 10)
y_test =tf.keras.utils.to_categorical(y_test,10)
# Out:
# (60000, 28, 28)

# %%
tf.model = tf.keras.Sequential()
batch_size = 100
l_rate =0.001
drop_rate = 0.3
tf.model.add(tf.keras.layers.Dense(units = 512, input_dim = 784, activation='relu', kernel_initializer='glorot_normal'))
tf.model.add(tf.keras.layers.Dropout(drop_rate))
tf.model.add(tf.keras.layers.Dense(units = 512, input_dim = 512, activation='relu', kernel_initializer='glorot_normal'))
tf.model.add(tf.keras.layers.Dropout(drop_rate))
tf.model.add(tf.keras.layers.Dense(units = 512, input_dim = 512, activation='relu', kernel_initializer='glorot_normal'))
tf.model.add(tf.keras.layers.Dropout(drop_rate))
tf.model.add(tf.keras.layers.Dense(units = 512, input_dim = 512, activation='relu', kernel_initializer='glorot_normal'))
tf.model.add(tf.keras.layers.Dropout(drop_rate))
tf.model.add(tf.keras.layers.Dense(units = 10, input_dim = 256, activation='softmax', kernel_initializer=initializer))
tf.model.compile(loss ='categorical_crossentropy', optimizer= tf.optimizers.Adam(lr=l_rate), metrics = ['accuracy'])
tf.model.summary()
# Out:
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_31 (Dense)            (None, 512)               401920
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_32 (Dense)            (None, 512)               262656
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_33 (Dense)            (None, 512)               262656
#
#  dropout_2 (Dropout)         (None, 512)               0
#
#  dense_34 (Dense)            (None, 512)               262656
#
#  dropout_3 (Dropout)         (None, 512)               0
#
#  dense_35 (Dense)            (None, 10)                5130
#
# =================================================================
# Total params: 1,195,018
# Trainable params: 1,195,018
# Non-trainable params: 0
# _________________________________________________________________
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
tf.model.fit(x_train, y_train, batch_size=batch_size, epochs = 15)
# Out:
# Epoch 1/15
# 600/600 [==============================] - 14s 22ms/step - loss: 0.3055 - accuracy: 0.9056
# Epoch 2/15
# 600/600 [==============================] - 13s 22ms/step - loss: 0.1447 - accuracy: 0.9583
# Epoch 3/15
# 600/600 [==============================] - 13s 22ms/step - loss: 0.1133 - accuracy: 0.9667
# Epoch 4/15
# 600/600 [==============================] - 14s 23ms/step - loss: 0.0926 - accuracy: 0.9725
# Epoch 5/15
# 600/600 [==============================] - 14s 23ms/step - loss: 0.0841 - accuracy: 0.9751
# Epoch 6/15
# 600/600 [==============================] - 13s 22ms/step - loss: 0.0730 - accuracy: 0.9787
# Epoch 7/15
# 600/600 [==============================] - 14s 22ms/step - loss: 0.0701 - accuracy: 0.9799
# Epoch 8/15
# 600/600 [==============================] - 13s 22ms/step - loss: 0.0653 - accuracy: 0.9809
# Epoch 9/15
# 600/600 [==============================] - 13s 22ms/step - loss: 0.0574 - accuracy: 0.9832
# Epoch 10/15
# 600/600 [==============================] - 14s 22ms/step - loss: 0.0537 - accuracy: 0.9848
# Epoch 11/15
# 600/600 [==============================] - 13s 22ms/step - loss: 0.0516 - accuracy: 0.9849
# Epoch 12/15
# 600/600 [==============================] - 14s 23ms/step - loss: 0.0503 - accuracy: 0.9847
# Epoch 13/15
# 600/600 [==============================] - 13s 22ms/step - loss: 0.0463 - accuracy: 0.9865
# Epoch 14/15
# 600/600 [==============================] - 14s 23ms/step - loss: 0.0451 - accuracy: 0.9868
# Epoch 15/15
# 600/600 [==============================] - 13s 22ms/step - loss: 0.0423 - accuracy: 0.9875

# %%
y_predicted = tf.model.predict(x_test)

for x in range(0,10):
  random_index = random.randint(0, x_test.shape[0] - 1)
  print("index: ", random_index,
        "actual y : ", np.argmax(y_test[random_index]),
        "predicted y : ", np.argmax(y_predicted[random_index]))
# Out:
# index:  4583 actual y :  5 predicted y :  5
# index:  1434 actual y :  1 predicted y :  1
# index:  5258 actual y :  1 predicted y :  1
# index:  2548 actual y :  9 predicted y :  9
# index:  2375 actual y :  4 predicted y :  4
# index:  5930 actual y :  0 predicted y :  0
# index:  9335 actual y :  1 predicted y :  1
# index:  5635 actual y :  3 predicted y :  3
# index:  4473 actual y :  0 predicted y :  0
# index:  6022 actual y :  9 predicted y :  9

# %%
evaluation = tf.model.evaluate(x_test, y_test)
print(evaluation)
# Out:
# 313/313 [==============================] - 1s 5ms/step - loss: 0.0756 - accuracy: 0.9811
# [0.07564399391412735, 0.9811000227928162]
